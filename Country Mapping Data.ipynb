# %% [markdown]
# # Country & Nationality mapping
#
# In many instances we will need to be able to convert between country and nationality when connecting people and companies to countries.
#
# We have three different source files that we can use, natively stored as JSON we will convert them to pickles for reasy use within python. The 3 files are:
#
# - Country names to country code mappings
# - Country code to country name mappings
# - Nationality to country code mappings

# %%
import json
import pandas as pd

# %% [markdown]
# ### Country codes to names

# %%
country_codes_2_names = json.load(open('data/clean_country_code_map.json', 'r'))

# %%
country_codes_2_names
# Out:
# {'AD': 'ANDORRA',
#  'AE': 'UNITED ARAB EMIRATES',
#  'AF': 'AFGHANISTAN',
#  'AG': 'ANTIGUA & BARBUDA',
#  'AL': 'ALBANIA',
#  'AM': 'ARMENIA',
#  'AO': 'ANGOLA',
#  'AR': 'ARGENTINA',
#  'AS': 'AMERICAN SAMOA',
#  'AT': 'AUSTRIA',
#  'AU': 'AUSTRALIA',
#  'AW': 'ARUBA',
#  'AX': 'ÌÉLAND ISLANDS',
#  'AZ': 'AZERBAIJAN',
#  'BA': 'BOSNIA',
#  'BB': 'BARBADOS',
#  'BD': 'BANGLADESH',
#  'BE': 'BELGIUM',
#  'BG': 'BULGARIA',
#  'BH': 'BAHRAIN',
#  'BI': 'BURUNDI',
#  'BJ': 'BENIN',
#  'BM': 'BERMUDA',
#  'BN': 'BRUNEI',
#  'BO': 'BOLIVIA',
#  'BR': 'BRAZIL',
#  'BS': 'BAHAMAS',
#  'BT': 'BHUTAN',
#  'BW': 'BOTSWANA',
#  'BY': 'BELARUS',
#  'BZ': 'BELIZE',
#  'CA': 'CANADA',
#  'CD': 'CONGO - KINSHASA',
#  'CF': 'CENTRAL AFRICAN REPUBLIC',
#  'CG': 'CONGO - BRAZZAVILLE',
#  'CH': 'SWITZERLAND',
#  'CI': 'CÌ«TE D\x89ÛªIVOIRE',
#  'CK': 'COOK ISLANDS',
#  'CL': 'CHILE',
#  'CM': 'CAMEROON',
#  'CN': 'CHINA',
#  'CO': 'COLOMBIA',
#  'CR': 'COSTA RICA',
#  'CU': 'CUBA',
#  'CY': 'CYPRUS',
#  'CZ': 'CZECHIA',
#  'DE': 'GERMANY',
#  'DJ': 'DJIBOUTI',
#  'DK': 'DENMARK',
#  'DM': 'DOMINICA',
#  'DO': 'DOMINICAN REPUBLIC',
#  'DQ': 'DQ',
#  'DZ': 'ALGERIA',
#  'EC': 'ECUADOR',
#  'EE': 'ESTONIA',
#  'EG': 'EGYPT',
#  'ER': 'ERITREA',
#  'ES': 'SPAIN',
#  'ET': 'ETHIOPIA',
#  'FI': 'FINLAND',
#  'FJ': 'FIJI',
#  'FR': 'FRANCE',
#  'GA': 'GABON',
#  'GB': 'UK',
#  'GD': 'GRENADA',
#  'GE': 'GEORGIA',
#  'GF': 'FRENCH GUIANA',
#  'GG': 'GUERNSEY',
#  'GH': 'GHANA',
#  'GI': 'GIBRALTAR',
#  'GM': 'GAMBIA',
#  'GN': 'GUINEA',
#  'GP': 'GUADELOUPE',
#  'GR': 'GREECE',
#  'GT': 'GUATEMALA',
#  'GW': 'GUINEA-BISSAU',
#  'GY': 'GUYANA',
#  'HK': 'HONG KONG',
#  'HN': 'HONDURAS',
#  'HR': 'CROATIA',
#  'HT': 'HAITI',
#  'HU': 'HUNGARY',
#  'ID': 'INDONESIA',
#  'IE': 'IRELAND',
#  'IL': 'ISRAEL',
#  'IM': 'ISLE OF MAN',
#  'IN': 'INDIA',
#  'IQ': 'IRAQ',
#  'IR': 'IRAN',
#  'IS': 'ICELAND',
#  'IT': 'ITALY',
#  'JM': 'JAMAICA',
#  'JO': 'JORDAN',
#  'JP': 'JAPAN',
#  'KE': 'KENYA',
#  'KG': 'KYRGYZSTAN',
#  'KH': 'CAMBODIA',
#  'KI': 'KIRIBATI',
#  'KN': 'ST. KITTS & NEVIS',
#  'KP': 'NORTH KOREA',
#  'KR': 'SOUTH KOREA',
#  'KW': 'KUWAIT',
#  'KY': 'CAYMAN ISLANDS',
#  'KZ': 'KAZAKHSTAN',
#  'LB': 'LEBANON',
#  'LC': 'ST. LUCIA',
#  'LI': 'LIECHTENSTEIN',
#  'LK': 'SRI LANKA',
#  'LR': 'LIBERIA',
#  'LS': 'LESOTHO',
#  'LT': 'LITHUANIA',
#  'LU': 'LUXEMBOURG',
#  'LV': 'LATVIA',
#  'LY': 'LIBYA',
#  'MA': 'MOROCCO',
#  'MD': 'MOLDOVA',
#  'ME': 'MONTENEGRO',
#  'MG': 'MADAGASCAR',
#  'MK': 'MACEDONIA',
#  'MM': 'MYANMAR',
#  'MN': 'MONGOLIA',
#  'MO': 'MACAU',
#  'MR': 'MAURITANIA',
#  'MT': 'MALTA',
#  'MU': 'MAURITIUS',
#  'MV': 'MALDIVES',
#  'MW': 'MALAWI',
#  'MX': 'MEXICO',
#  'MY': 'MALAYSIA',
#  'MZ': 'MOZAMBIQUE',
#  'NA': 'NAMIBIA',
#  'NE': 'NIGER',
#  'NG': 'NIGERIA',
#  'NI': 'NICARAGUA',
#  'NL': 'NETHERLANDS',
#  'NO': 'NORWAY',
#  'NP': 'NEPAL',
#  'NR': 'NAURU',
#  'NZ': 'NEW ZEALAND',
#  'OM': 'OMAN',
#  'PA': 'PANAMA',
#  'PE': 'PERU',
#  'PG': 'PAPUA NEW GUINEA',
#  'PH': 'PHILIPPINES',
#  'PK': 'PAKISTAN',
#  'PL': 'POLAND',
#  'PR': 'PUERTO RICO',
#  'PS': 'PALESTINE',
#  'PT': 'PORTUGAL',
#  'PY': 'PARAGUAY',
#  'QA': 'QATAR',
#  'RO': 'ROMANIA',
#  'RS': 'SERBIA',
#  'RU': 'RUSSIA',
#  'RW': 'RWANDA',
#  'SA': 'SAUDI ARABIA',
#  'SC': 'SEYCHELLES',
#  'SD': 'SUDAN',
#  'SE': 'SWEDEN',
#  'SG': 'SINGAPORE',
#  'SI': 'SLOVENIA',
#  'SK': 'SLOVAKIA',
#  'SL': 'SIERRA LEONE',
#  'SM': 'SAN MARINO',
#  'SN': 'SENEGAL',
#  'SO': 'SOMALIA',
#  'ST': 'SÌ£O TOMÌ© & PRÌ?NCIPE',
#  'SV': 'EL SALVADOR',
#  'SY': 'SYRIA',
#  'SZ': 'SWAZILAND',
#  'TG': 'TOGO',
#  'TH': 'THAILAND',
#  'TJ': 'TAJIKISTAN',
#  'TL': 'TIMOR-LESTE',
#  'TM': 'TURKMENISTAN',
#  'TN': 'TUNISIA',
#  'TO': 'TONGA',
#  'TR': 'TURKEY',
#  'TT': 'TRINIDAD & TOBAGO',
#  'TW': 'TAIWAN',
#  'TZ': 'TANZANIA',
#  'UA': 'UKRAINE',
#  'UG': 'UGANDA',
#  'US': 'US',
#  'UY': 'URUGUAY',
#  'UZ': 'UZBEKISTAN',
#  'VC': 'ST. VINCENT & GRENADINES',
#  'VE': 'VENEZUELA',
#  'VG': 'BRITISH VIRGIN ISLANDS',
#  'VN': 'VIETNAM',
#  'VU': 'VANUATU',
#  'XK': 'KOSOVO',
#  'YE': 'YEMEN',
#  'ZA': 'SOUTH AFRICA',
#  'ZM': 'ZAMBIA',
#  'ZW': 'ZIMBABWE'}

# %%
pd.to_pickle(country_codes_2_names, "data/clean_country_code_map.pkl")

# %% [markdown]
# ### Country names to codes

# %%
country_names_2_codes = json.load(open("data/country_name_2_code_map.json", "r"))

# %%
country_names_2_codes
# Out:
# {'afghanistan': 'AF',
#  'albania': 'AL',
#  'algeria': 'DZ',
#  'american samoa': 'AS',
#  'andorra': 'AD',
#  'angola': 'AO',
#  'antigua & barbuda': 'AG',
#  'argentina': 'AR',
#  'armenia': 'AM',
#  'aruba': 'AW',
#  'australia': 'AU',
#  'austria': 'AT',
#  'azerbaijan': 'AZ',
#  'bahamas': 'BS',
#  'bahrain': 'BH',
#  'bangladesh': 'BD',
#  'barbados': 'BB',
#  'belarus': 'BY',
#  'belgium': 'BE',
#  'belize': 'BZ',
#  'benin': 'BJ',
#  'bermuda': 'BM',
#  'bhutan': 'BT',
#  'bolivia': 'BO',
#  'bosnia': 'BA',
#  'botswana': 'BW',
#  'brazil': 'BR',
#  'british virgin islands': 'VG',
#  'brunei': 'BN',
#  'bulgaria': 'BG',
#  'burundi': 'BI',
#  'cambodia': 'KH',
#  'cameroon': 'CM',
#  'canada': 'CA',
#  'cayman islands': 'KY',
#  'central african republic': 'CF',
#  'channel islands': 'CHANNEL ISLANDS',
#  'chile': 'CL',
#  'china': 'CN',
#  'colombia': 'CO',
#  'congo - brazzaville': 'CG',
#  'congo - kinshasa': 'CD',
#  'cook islands': 'CK',
#  'costa rica': 'CR',
#  'croatia': 'HR',
#  'cuba': 'CU',
#  'cyprus': 'CY',
#  'czechia': 'CZ',
#  'cì«te d\x89ûªivoire': 'CI',
#  'denmark': 'DK',
#  'djibouti': 'DJ',
#  'dominica': 'DM',
#  'dominican republic': 'DO',
#  'dq': 'DQ',
#  'ecuador': 'EC',
#  'egypt': 'EG',
#  'el salvador': 'SV',
#  'england': 'GB',
#  'england & wales': 'GB',
#  'england and wales': 'GB',
#  'eritrea': 'ER',
#  'estonia': 'EE',
#  'ethiopia': 'ET',
#  'fiji': 'FJ',
#  'finland': 'FI',
#  'france': 'FR',
#  'french guiana': 'GF',
#  'gabon': 'GA',
#  'gambia': 'GM',
#  'georgia': 'GE',
#  'germany': 'DE',
#  'ghana': 'GH',
#  'gibraltar': 'GI',
#  'great britain': 'GB',
#  'greece': 'GR',
#  'grenada': 'GD',
#  'guadeloupe': 'GP',
#  'guatemala': 'GT',
#  'guernsey': 'GG',
#  'guinea': 'GN',
#  'guinea-bissau': 'GW',
#  'guyana': 'GY',
#  'haiti': 'HT',
#  'honduras': 'HN',
#  'hong kong': 'HK',
#  'hungary': 'HU',
#  'iceland': 'IS',
#  'india': 'IN',
#  'indonesia': 'ID',
#  'iran': 'IR',
#  'iraq': 'IQ',
#  'ireland': 'IE',
#  'isle of man': 'IM',
#  'israel': 'IL',
#  'italy': 'IT',
#  'jamaica': 'JM',
#  'japan': 'JP',
#  'jersey': 'JE',
#  'jordan': 'JO',
#  'kazakhstan': 'KZ',
#  'kenya': 'KE',
#  'kiribati': 'KI',
#  'kosovo': 'XK',
#  'kuwait': 'KW',
#  'kyrgyzstan': 'KG',
#  'latvia': 'LV',
#  'lebanon': 'LB',
#  'lesotho': 'LS',
#  'liberia': 'LR',
#  'libya': 'LY',
#  'liechtenstein': 'LI',
#  'lithuania': 'LT',
#  'luxembourg': 'LU',
#  'macau': 'MO',
#  'macedonia': 'MK',
#  'madagascar': 'MG',
#  'malawi': 'MW',
#  'malaysia': 'MY',
#  'maldives': 'MV',
#  'malta': 'MT',
#  'mauritania': 'MR',
#  'mauritius': 'MU',
#  'mexico': 'MX',
#  'moldova': 'MD',
#  'mongolia': 'MN',
#  'montenegro': 'ME',
#  'morocco': 'MA',
#  'mozambique': 'MZ',
#  'myanmar': 'MM',
#  'namibia': 'NA',
#  'nan': nan,
#  'nauru': 'NR',
#  'nepal': 'NP',
#  'netherlands': 'NL',
#  'new zealand': 'NZ',
#  'nicaragua': 'NI',
#  'niger': 'NE',
#  'nigeria': 'NG',
#  'north korea': 'KP',
#  'northern ireland': 'GB',
#  'norway': 'NO',
#  'oman': 'OM',
#  'pakistan': 'PK',
#  'palestine': 'PS',
#  'panama': 'PA',
#  'papua new guinea': 'PG',
#  'paraguay': 'PY',
#  'peru': 'PE',
#  'philippines': 'PH',
#  'poland': 'PL',
#  'portugal': 'PT',
#  'puerto rico': 'PR',
#  'qatar': 'QA',
#  'republic of ghana': 'GH',
#  'romania': 'RO',
#  'russia': 'RU',
#  'rwanda': 'RW',
#  'san marino': 'SM',
#  'saudi arabia': 'SA',
#  'scotland': 'GB',
#  'scotland uk': 'GB',
#  'scotland united kingdom': 'GB',
#  'scotland, uk': 'GB',
#  'senegal': 'SN',
#  'serbia': 'RS',
#  'seychelles': 'SC',
#  'sierra leone': 'SL',
#  'singapore': 'SG',
#  'slovakia': 'SK',
#  'slovenia': 'SI',
#  'somalia': 'SO',
#  'south africa': 'ZA',
#  'south korea': 'KR',
#  'spain': 'ES',
#  'sri lanka': 'LK',
#  'st. kitts & nevis': 'KN',
#  'st. lucia': 'LC',
#  'st. vincent & grenadines': 'VC',
#  'sudan': 'SD',
#  'swaziland': 'SZ',
#  'sweden': 'SE',
#  'switzerland': 'CH',
#  'syria': 'SY',
#  'sì£o tomì© & prì?ncipe': 'ST',
#  'taiwan': 'TW',
#  'tajikistan': 'TJ',
#  'tanzania': 'TZ',
#  'thailand': 'TH',
#  'timor-leste': 'TL',
#  'togo': 'TG',
#  'tonga': 'TO',
#  'trinidad & tobago': 'TT',
#  'tunisia': 'TN',
#  'turkey': 'TR',
#  'turkmenistan': 'TM',
#  'uganda': 'UG',
#  'uk': 'GB',
#  'ukraine': 'UA',
#  'united arab emirates': 'AE',
#  'united kingdom': 'GB',
#  'united states': 'US',
#  'united states of america': 'US',
#  'uruguay': 'UY',
#  'us': 'US',
#  'usa': 'US',
#  'uzbekistan': 'UZ',
#  'vanuatu': 'VU',
#  'venezuela': 'VE',
#  'vietnam': 'VN',
#  'wales': 'GB',
#  'yemen': 'YE',
#  'zambia': 'ZM',
#  'zimbabwe': 'ZW',
#  'ìéland islands': 'AX'}

# %%
pd.to_pickle(country_names_2_codes, "data/combined_country_map.pkl")

# %% [markdown]
# ### Nationality

# %%
nationality_2_codes = json.load(open("data/nationality_map.json", "r"))

# %%
nationality_2_codes
# Out:
# {'british': 'GB',
#  '(blank)': 'DQ',
#  'english': 'GB',
#  'irish': 'IE',
#  'polish': 'PL',
#  'indian': 'IN',
#  'chinese': 'CN',
#  'uk': 'GB',
#  'italian': 'IT',
#  'german': 'DE',
#  'romanian': 'RO',
#  'french': 'FR',
#  'pakistani': 'PK',
#  'scottish': 'GB',
#  'australian': 'AU',
#  'american': 'US',
#  'nigerian': 'NG',
#  'bulgarian': 'BG',
#  'spanish': 'ES',
#  'welsh': 'GB',
#  'united kingdom': 'GB',
#  'dutch': 'NL',
#  'lithuanian': 'LT',
#  'south african': 'ZA',
#  'swedish': 'SE',
#  'hungarian': 'HU',
#  'greek': 'GR',
#  'norwegian': 'NO',
#  'zimbabwean': 'ZW',
#  'portuguese': 'PT',
#  'new zealander': 'NZ',
#  'canadian': 'CA',
#  'turkish': 'TR',
#  'northern irish': 'GB',
#  'russian': 'RU',
#  'belgian': 'BE',
#  'danish': 'DK',
#  'malaysian': 'MY',
#  'bangladeshi': 'BD',
#  'austrian': 'AT',
#  'latvian': 'LV',
#  'usa': 'US',
#  'czech': 'CZ',
#  'swiss': 'CH',
#  'british citizen': 'GB',
#  'iranian': 'IR',
#  'ghanaian': 'GH',
#  'britsh': 'GB',
#  'ukrainian': 'UA',
#  'brazilian': 'BR',
#  'sri lankan': 'LK',
#  'japanese': 'JP',
#  'israeli': 'IL',
#  'slovak': 'SK',
#  'cypriot': 'CY',
#  'bristish': 'GB',
#  'united states': 'US',
#  'jamaican': 'JM',
#  'new zealand': 'NZ',
#  'egyptian': 'EG',
#  'kenyan': 'KE',
#  'brittish': 'GB',
#  'china': 'CN',
#  'finnish': 'FI',
#  'netherlands': 'NL',
#  'thai': 'TH',
#  'albanian': 'AL',
#  'singaporean': 'SG',
#  'nepalese': 'NP',
#  'romania': 'RO',
#  'estonian': 'EE',
#  'iraqi': 'IQ',
#  'croatian': 'HR',
#  'slovakian': 'SK',
#  'pakistan': 'PK',
#  'mexican': 'MX',
#  'south korean': 'KR',
#  'filipino': 'PH',
#  'nigeria': 'NG',
#  'maltese': 'MT',
#  'mauritian': 'MR',
#  'lebanese': 'LB',
#  'syrian': 'SY',
#  'uk citizen': 'GB',
#  'brtish': 'GB',
#  'afghan': 'AF',
#  'slovenian': 'SI',
#  'jamaica': 'JM',
#  'taiwanese': 'TW',
#  'united states of america': 'US',
#  'ukraine': 'UA',
#  'vietnamese': 'VN',
#  'srilankan': 'LK',
#  'britsih': 'GB',
#  'czech republic': 'CZ',
#  'portugese': 'PT',
#  'ugandan': 'UG',
#  'gb': 'GB',
#  'england': 'GB',
#  'india': 'IN',
#  'zambian': 'ZM',
#  'colombian': 'CO',
#  'british virgin islander': 'VG',
#  'france': 'FR',
#  'belgium': 'BE',
#  'italy': 'IT',
#  'jordanian': 'JO',
#  'saudi arabian': 'SA',
#  'spain': 'ES',
#  'venezuelan': 'VE',
#  'algerian': 'DZ',
#  'tanzanian': 'TZ',
#  'poland': 'PL',
#  'us': 'US',
#  'cameroonian': 'CM',
#  'serbian': 'RS',
#  'ireland': 'IE',
#  'malawian': 'MW',
#  'bulgaria': 'BG',
#  'germany': 'DE',
#  'libyan': 'LY',
#  'icelandic': 'IS',
#  'kuwaiti': 'KW',
#  'sierra leonean': 'SL',
#  'sudanese': 'SD',
#  'argentine': 'AR',
#  'bangladesh': 'BD',
#  'georgian': 'GE',
#  'moroccan': 'MA',
#  'philippine': 'PH',
#  'us citizen': 'US',
#  'white british': 'GB',
#  'belarusian': 'BY',
#  'ukranian': 'UA',
#  'lithuania': 'LT',
#  'somali': 'SO',
#  'hong kong': 'HK',
#  'moldovan': 'MD',
#  'zimbabwe': 'ZW',
#  'brirish': 'GB',
#  'tunisian': 'TN',
#  'korean': 'KR',
#  'portugal': 'PT',
#  'uk british': 'GB',
#  'australia': 'AU',
#  'bitish': 'GB',
#  'britiish': 'GB',
#  'u.k.': 'GB',
#  'great britain': 'GB',
#  'indonesian': 'ID',
#  'malaysia': 'MY',
#  'n irish': 'GB',
#  'azerbaijani': 'AZ',
#  'birtish': 'GB',
#  'brithish': 'GB',
#  'chilean': 'CL',
#  'gambian': 'GM',
#  'trinidad and tobago': 'TT',
#  'trinidadian': 'TT',
#  'slovakia': 'SK',
#  'sweden': 'SE',
#  'uzbek': 'UZ',
#  'armenian': 'AM',
#  'briish': 'GB',
#  'kosovan': 'XK',
#  'palestinian': 'PS',
#  'austria': 'AT',
#  'citizen of seychelles': 'SC',
#  'greece': 'GR',
#  'peruvian': 'PE',
#  'brit': 'GB',
#  'brtitish': 'GB',
#  'deutsch': 'DE',
#  'gbr': 'GB',
#  'netherland': 'NL',
#  'switzerland': 'CH',
#  'afghanistan': 'AF',
#  'ghanian': 'GH',
#  'latvia': 'LV',
#  'uzbekistan': 'UZ',
#  'saudi': 'SA',
#  'congolese': 'CD',
#  'kazakh': 'KZ',
#  'luxembourger': 'LU',
#  'btitish': 'GB',
#  'canada': 'CA',
#  'hellenic': 'GR',
#  'ivorian': 'CI',
#  'argentinian': 'AR',
#  'barbadian': 'BB',
#  'bri': 'GB',
#  'finland': 'FI',
#  'hungary': 'HU',
#  'united arab emirates': 'AE',
#  'briitish': 'GB',
#  'british/english': 'GB',
#  'nepali': 'NP',
#  'nigerien': 'NE',
#  'turkey': 'TR',
#  'britiah': 'GB',
#  'britis': 'GB',
#  'dominican': 'DO',
#  'kazakhstan': 'KZ',
#  'british english': 'GB',
#  'cyprus': 'CY',
#  'russian federation': 'RU',
#  'singapore': 'SG',
#  'south africa': 'ZA',
#  'bahraini': 'BH',
#  'biritish': 'GB',
#  'costa rican': 'CR',
#  'eritrean': 'ER',
#  'uk national': 'GB',
#  'vincentian': 'VC',
#  'brititsh': 'GB',
#  'icelander': 'IS',
#  'macedonian': 'MK',
#  'myanmar': 'MM',
#  'n. irish': 'GB',
#  'panamanian': 'PA',
#  'philippino': 'PH',
#  'sri lanka': 'LK',
#  'taiwan': 'TW',
#  'briitsh': 'GB',
#  'ghana': 'GH',
#  'iran': 'IR',
#  'n.irish': 'IR',
#  'philippines': 'PH',
#  'serbia and montenegro': 'RS',
#  'south korea': 'KR',
#  'brisith': 'GB',
#  'other': 'DQ',
#  'rumanian': 'RO',
#  'bosnian': 'BA',
#  'denmark': 'DK',
#  'iraq': 'IQ',
#  'kosovo': 'XK',
#  'madagascan': 'MG',
#  'qatari': 'QA',
#  'republic of china': 'CN',
#  'romainian': 'RO',
#  'yemeni': 'YE',
#  'belarus': 'BY',
#  'botswana': 'BW',
#  'brirtish': 'GB',
#  'britih': 'GB',
#  'british.': 'GB',
#  'nationality unknown': 'DQ',
#  'fijian': 'FJ',
#  'guyanese': 'GY',
#  'liechtenstein': 'LI',
#  'namibian': 'nan',
#  'norway': 'NO',
#  'slovak republic': 'SK',
#  'somalia': 'SO',
#  'st kitts and nevis': 'KN',
#  'afghani': 'AF',
#  'angolan': 'AO',
#  'argentina': 'AR',
#  'botswanan': 'BW',
#  'britisg': 'GB',
#  'ethiopian': 'ET',
#  'guinean': 'GN',
#  'israel': 'IL',
#  'italia': 'IT',
#  'liberian': 'LY',
#  'mongolian': 'MN',
#  'motswana': 'BW',
#  'republic of korea': 'KR',
#  'russia': 'RU',
#  'wales': 'GB',
#  'afgan': 'AF',
#  'austrailian': 'AU',
#  'biritsh': 'GB',
#  'britain': 'GB',
#  'cameroon': 'CM',
#  'cornish': 'GB',
#  'great british': 'GB',
#  'kuwait': 'KW',
#  'roumanian': 'RO',
#  'scots': 'GB',
#  'albania': 'AL',
#  'bahamian': 'BS',
#  'brisitsh': 'GB',
#  'britich': 'GB',
#  'britisch': 'GB',
#  'britrish': 'GB',
#  'emirati': 'AE',
#  'estonia': 'EE',
#  'mauritanian': 'MR',
#  'nan': 'DQ',
#  'saudi arabia': 'SA',
#  'scotish': 'GB',
#  'seychelles': 'SC',
#  'st. kitts and nevis': 'KN',
#  'swazi': 'SZ',
#  'syria': 'SY',
#  'turkmen': 'TM',
#  'u.s.a.': 'US',
#  'uruguayan': 'UY',
#  'vietnam': 'VN',
#  'argentinean': 'AR',
#  'brasilian': 'BR',
#  'citizen of mauritius': 'MU',
#  'eire': 'IE',
#  'eng': 'GB',
#  'hong kong sar': 'HK',
#  'kenya': 'KE',
#  'luxembourg': 'LU',
#  'mauritius': 'MU',
#  'nederlands': 'NL',
#  'northern ireland': 'GB',
#  'republic of ireland': 'IE',
#  'somalian': 'SO',
#  'belguim': 'BE',
#  'belizean': 'BZ',
#  'brazil': 'BR',
#  'british uk': 'GB',
#  'britishh': 'GB',
#  'brtitsh': 'GB',
#  'cuban': 'CU',
#  'cymro': 'GB',
#  'democratic republic of the congo': 'CD',
#  'ecuadorian': 'EC',
#  'egypt': 'EG',
#  'isreali': 'IL',
#  'moldovian': 'MD',
#  'nationality': 'DQ',
#  'omani': 'OM',
#  'portuguesa': 'PT',
#  'scotland': 'GB',
#  'senegalese': 'SN',
#  'spainish': 'ES',
#  'sudan': 'SD',
#  'the netherlands': 'NL',
#  'uae': 'AE',
#  'uganda': 'UG',
#  'united kingdon': 'GB',
#  'uzbekistani': 'UZ',
#  'bolivian': 'BO',
#  'britihs': 'GB',
#  'british national': 'GB',
#  'british national (overseas)': 'GB',
#  'british national overseas': 'GB',
#  'british subject': 'GB',
#  'brotish': 'GB',
#  'brtiish': 'GB',
#  'columbian': 'CO',
#  'costa rica': 'CR',
#  'ecuadorean': 'EC',
#  'engish': 'GB',
#  'englsih': 'GB',
#  'guernsey': 'GG',
#  'holland': 'NL',
#  'italien': 'IT',
#  'japan': 'JP',
#  'kurdish': 'TR',
#  'liberia': 'LR',
#  'moldavian': 'MD',
#  'morocco': 'MA',
#  'saint lucian': 'LC',
#  'slovenia': 'SI',
#  'thailand': 'TH',
#  'turkmenistan': 'TM',
#  'afganistan': 'AF',
#  'belorussian': 'BY',
#  'brfitish': 'GB',
#  'british asian': 'GB',
#  'britisih': 'GB',
#  'britush': 'GB',
#  'croat': 'HR',
#  'cymraes': 'GB',
#  'finish': 'GB',
#  'ghanain': 'GH',
#  'kosova': 'XK',
#  'kyrgyz': 'KG',
#  'luxembourgish': 'LU',
#  'maldivian': 'MV',
#  'moldova': 'MD',
#  'nepal': 'NP',
#  'phillipino': 'PH',
#  'portugeuse': 'PT',
#  'potuguese': 'PT',
#  'romana': 'RO',
#  'rwandan': 'RW',
#  'seychellois': 'SC',
#  'swede': 'SE',
#  'tajik': 'TH',
#  'unknown': 'DQ',
#  'algeria': 'DZ',
#  'b ritish': 'GB',
#  'beninese': 'BJ',
#  'bhutanese': 'BT',
#  'black british': 'GB',
#  'brisish': 'GB',
#  'brit/eng': 'GB',
#  'briti': 'GB',
#  'british - english': 'GB',
#  'british citizenship': 'GB',
#  'british cornish': 'GB',
#  'britisj': 'GB',
#  'britisn': 'GB',
#  'brtisih': 'GB',
#  'burmese': 'MM',
#  'cymro / cymraes': 'GB',
#  'czechoslovakian': 'CZ',
#  'egy': 'EG',
#  'englis': 'GB',
#  'espanola': 'ES',
#  'francaise': 'FR',
#  'guatemalan': 'GT',
#  'irani': 'IR',
#  'jamacian': 'JM',
#  'jordan': 'JO',
#  'malasian': 'MY',
#  'african': 'DQ',
#  'nederland': 'NL',
#  'nederlandse': 'NL',
#  'new zelander': 'NZ',
#  'nigerain': 'NG',
#  'paraguayan': 'PY',
#  'qatar': 'QA',
#  'singapore citizen': 'SG',
#  'slovene': 'SI',
#  'srilanka': 'LK',
#  'togolese': 'CD',
#  'tunesian': 'TN',
#  'turksih': 'TM',
#  'u k': 'GB',
#  'u.kingdom': 'GB',
#  'usa/uk': 'SA',
#  'welsh british': 'GB',
#  'west indian': 'IN',
#  'afghanistani': 'AF',
#  'american - usa': 'US',
#  'austrain': 'AU',
#  'azerbaijan': 'AZ',
#  'bahrain': 'BH',
#  'bosnia and herzegovinian': 'BA',
#  'briritsh': 'GB',
#  'bristol': 'GB',
#  'brithis': 'GB',
#  'brithsh': 'GB',
#  'britiash': 'GB',
#  'britidh': 'GB',
#  'britishi': 'GB',
#  'bruneian': 'BN',
#  'burundi': 'BI',
#  'cambodian': 'KH',
#  'central african republic': 'CF',
#  'chines': 'CN',
#  'chineses': 'CN',
#  'croatia': 'HR',
#  'croation': 'HR',
#  'cymreig': 'GB',
#  'dominican republic': 'DO',
#  'ecuador': 'EC',
#  'emaratis': 'AE',
#  'emirian': 'IE',
#  'english / british': 'GB',
#  'european': 'DQ',
#  'fiji': 'FJ',
#  'gabonese': 'GA',
#  'honduran': 'HN',
#  'hong kong chinese': 'HK',
#  'hong kong, china': 'HK',
#  'hongkong': 'HK',
#  'indain': 'IN',
#  'irish (roi)': 'IE',
#  'lativan': 'LV',
#  'lebanon': 'LB',
#  'lesotho': 'LS',
#  'libya': 'LY',
#  'manx': 'IM',
#  'montenegro': 'ME',
#  'morrocan': 'MA',
#  'new zealand citizen': 'NZ',
#  'newzealand': 'NZ',
#  'nicaraguan': 'NI',
#  'nothern irish': 'GB',
#  'phillipines': 'PH',
#  'republic of belarus': 'BY',
#  'roman': 'RO',
#  'romenian': 'RO',
#  'serbia': 'RS',
#  'sierra leone': 'SL',
#  'slovenija': 'SI',
#  'southafrican': 'ZA',
#  'spaniard': 'ES',
#  'st lucian': 'LC',
#  'sudani': 'SD',
#  'sweedish': 'SE',
#  'tajikistan': 'TJ',
#  'turk': 'TR',
#  'u k citizen': 'GB',
#  'u.k': 'GB',
#  'u.s.': 'US',
#  'ugandian': 'UG',
#  'uk scottish': 'GB',
#  'united kindom': 'GB',
#  'united kingdom national': 'GB',
#  'african american': 'US',
#  'amercian': 'US',
#  'america': 'US',
#  'anglo-italian': 'IT',
#  'arabic': 'DQ',
#  'austrialian': 'AU',
#  'bangaladeshi': 'BD',
#  'bangledeshi': 'BD',
#  'beitish': 'GB',
#  'belge': 'BE',
#  'belgiam': 'BE',
#  'belgum': 'BE',
#  'belize': 'BZ',
#  'bermudian': 'BM',
#  'bolivia': 'BO',
#  'brazillian': 'BR',
#  'breitish': 'GB',
#  'brith': 'GB',
#  'british-': 'GB',
#  'british / english': 'GB',
#  'british caribbean': 'GB',
#  'british citizens': 'GB',
#  'british national oversea': 'GB',
#  'british overseas': 'GB',
#  'british sikh': 'GB',
#  'british/african': 'GB',
#  'british/welsh': 'GB',
#  'britisjh': 'GB',
#  'britisk': 'GB',
#  'britisth': 'GB',
#  'britiswh': 'GB',
#  'britosh': 'GB',
#  'brritish': 'GB',
#  'brutish': 'GB',
#  'btritish': 'GB',
#  'candian': 'CA',
#  'chinese (prc)': 'CN',
#  'chinses': 'CN',
#  'chinsese': 'CN',
#  'colombia': 'CO',
#  'cuba': 'CU',
#  'czeck republic': 'CZ',
#  'czekish': 'CZ',
#  'dane': 'DK',
#  'danmark': 'DK',
#  'deutch': 'NL',
#  'arabian': 'DQ',
#  'egyption': 'EG',
#  'engkish': 'GB',
#  'engliah': 'GB',
#  'english british': 'GB',
#  'english/british': 'GB',
#  'ethiopia': 'ET',
#  'flipino': 'PH',
#  'franch': 'FR',
#  'frech': 'FR',
#  'gambia': 'GM',
#  'gibraltarian': 'GI',
#  'great britian': 'GB',
#  'hkg': 'HK',
#  'hungaryan': 'HU',
#  'indonesia': 'ID',
#  'irish republic': 'IE',
#  'irleand': 'IR',
#  'israili': 'IL',
#  'ivoirian': 'CI',
#  'ivory coast': 'CI',
#  'japenese': 'JP',
#  'jordinian': 'JO',
#  'kazakhstani': 'KZ',
#  'korea': 'KR',
#  'kosovon': 'XK',
#  'kyrgyzstan': 'KG',
#  'latvijas': 'LV',
#  'libian': 'LY',
#  'liechtensteiner': 'LI',
#  'lituanian': 'LT',
#  'luxembourgian': 'LU',
#  'madagascar': 'MG',
#  'malawi': 'MW',
#  'malian': 'MT',
#  'mexico': 'MX',
#  'monegasque': 'MN',
#  'montenegran': 'ME',
#  'mozambique': 'MZ',
#  'n. ireland': 'IE',
#  'n.ireland': 'GB',
#  'nagerian': 'NG',
#  'napalese': 'NP',
#  'nauruan': 'NR',
#  'netherlander': 'NL',
#  'north korean': 'KP',
#  'norwegain': 'NO',
#  'norweigan': 'NO',
#  'nz': 'NZ',
#  'pakinstain': 'PK',
#  'paksitani': 'PK',
#  'palestine': 'PS',
#  'philipines': 'PH',
#  'philipino': 'PH',
#  'portguese': 'PT',
#  'portugues': 'PT',
#  'channel islander': 'DQ',
#  'qatri': 'QA',
#  'republic of cyprus': 'CY',
#  'republic of india': 'IN',
#  'ritish': 'GB',
#  'rmanian': 'RO',
#  'romanians': 'RO',
#  'romanien': 'RO',
#  'saint vincent and th': 'VC',
#  'salvadorian': 'SV',
#  'singapore national': 'SG',
#  'solvakian': 'SK',
#  'south-african': 'ZA',
#  'spannish': 'ES',
#  'sri laknan': 'LK',
#  'sri-lankan': 'LK',
#  'st kitts & nevis': 'KN',
#  'suisse': 'CH',
#  'swedis': 'SE',
#  'swidish': 'SE',
#  'togo': 'TG',
#  'kashmiri': 'DQ',
#  'u s': 'US',
#  'u. k.': 'GB',
#  'ucrainian': 'UA',
#  'uk and swiss': 'CH',
#  'uk english': 'GB',
#  'uk/gb': 'CU',
#  'ukrainean': 'UA',
#  'united states citizen': 'US',
#  'untied kingdom': 'GB',
#  'uruguay': 'UY',
#  'venezuela': 'VE',
#  'welsh/british': 'GB',
#  'yemen': 'YE',
#  'yemenese': 'YE',
#  'yugoslavia': 'DQ',
#  'yugoslavian': 'DQ',
#  'zambia': 'ZM',
#  'zimbabawean': 'ZW',
#  'zimbabean': 'ZW',
#  'zimbabwian': 'ZW',
#  'zimbawean': 'ZW',
#  'mixed race - white / black afro caribbean': 'DQ',
#  'moorish': 'DQ',
#  '.british': 'GB',
#  'nubian': 'DQ',
#  'afgani': 'AF',
#  'afghansitan': 'AF',
#  'albani': 'AL',
#  'albaninan': 'AL',
#  'americam': 'US',
#  'american (us)': 'US',
#  'american citizen': 'US',
#  'amrican': 'US',
#  'andorra': 'AD',
#  'andorran': 'AD',
#  'anglo/irish': 'IE',
#  'anglo/italian': 'IT',
#  'anglo-american': 'US',
#  'antigua and barbuda': 'AG',
#  'antiguan and barbudan': 'AG',
#  'director': 'DQ',
#  'arerbaijan': 'AZ',
#  'argentianian': 'AR',
#  'armemnian': 'AM',
#  'armenia': 'AM',
#  'asian british': 'GB',
#  'austalian': 'AU',
#  'austarlian': 'AU',
#  'austrailia': 'AU',
#  'australain': 'AU',
#  'australan': 'AU',
#  'australina': 'AU',
#  'australlian': 'AU',
#  'austriam': 'AT',
#  'austrian/american': 'AU',
#  'autralian': 'AU',
#  'awhite british': 'GB',
#  'bagladesh': 'BD',
#  'bagladeshi': 'BD',
#  'bahgladeshi': 'BD',
#  'balarus': 'BY',
#  'balinese': 'BJ',
#  'bangaladesh': 'BD',
#  'bangaldeshi': 'BD',
#  'bangla desh': 'BD',
#  'banglandesh': 'BD',
#  'banladesh': 'BD',
#  'barbados': 'BB',
#  'bartish': 'GB',
#  'batswana': 'BW',
#  'bejing': 'BJ',
#  'belarasian': 'BY',
#  'belarussian': 'BY',
#  'belg': 'BE',
#  'belgien': 'BE',
#  'belizian': 'BZ',
#  'belurus': 'BY',
#  'bermudan': 'BM',
#  'bfritish': 'GB',
#  'biitish': 'GB',
#  'birish': 'GB',
#  'birthish': 'GB',
#  'company director': 'DQ',
#  'birtsh': 'GB',
#  'bitish citizen': 'GB',
#  'bolgarian': 'BG',
#  'bolivan': 'BO',
#  'bosnia': 'BA',
#  'bosnia & herzegovinian': 'BA',
#  'bosnia and herzegovina': 'BA',
#  'bosnia and herzergov': 'BA',
#  'bosnian / herzegovinian': 'BA',
#  'br': 'BR',
#  'br5itish': 'GB',
#  'brasil': 'BR',
#  'brasilan': 'BR',
#  'brasileira': 'BR',
#  'braziian': 'BR',
#  'brazilean': 'BR',
#  'brazillan': 'BR',
#  'brirtsh': 'GB',
#  'brishish': 'GB',
#  'brisitish': 'GB',
#  'bristh': 'GB',
#  'bristiah': 'GB',
#  'bristih': 'GB',
#  'bristis': 'GB',
#  'bristish bangladeshi': 'GB',
#  'bristish citizen': 'GB',
#  'bristsh': 'GB',
#  'brit / english': 'GB',
#  'brit/scot': 'GB',
#  'brit6ish': 'GB',
#  'britash': 'GB',
#  'brithish english': 'GB',
#  'britinsh': 'GB',
#  'britiosh': 'GB',
#  'britisah': 'GB',
#  'britisb': 'GB',
#  'british - uk citizen': 'GB',
#  'british (bermudian)': 'GB',
#  'british (canada born)': 'GB',
#  'british (naturalised)': 'GB',
#  'british (scots)': 'GB',
#  'british (welsh)': 'GB',
#  'british / scottish': 'GB',
#  'british / welsh': 'GB',
#  'british /english': 'GB',
#  'british african': 'GB',
#  'british amercian': 'US',
#  'british bengali': 'GB',
#  'british citizenship/ukrainian': 'GB',
#  'british cityzen': 'GB',
#  'british citzen': 'GB',
#  'british european': 'GB',
#  'british norfolk': 'GB',
#  'british resident': 'GB',
#  'british scott': 'GB',
#  'british welsh': 'GB',
#  'british, english': 'GB',
#  'british,uk': 'GB',
#  'british/ english': 'GB',
#  'british/ eu national': 'GB',
#  'british/asian': 'GB',
#  'british/scottish': 'GB',
#  'british-american': 'GB',
#  'britishbritish': 'GB',
#  'britishcitizen': 'GB',
#  'britisht': 'GB',
#  'britishu': 'GB',
#  'british-united kingdom': 'GB',
#  'britiss': 'GB',
#  'britisy': 'GB',
#  'brititish': 'GB',
#  'briton': 'GB',
#  'brits': 'GB',
#  'britsh - english': 'GB',
#  'britshi': 'GB',
#  'britsish': 'GB',
#  'britsith': 'GB',
#  'brittiish': 'GB',
#  'brittsh': 'GB',
#  'brituish': 'GB',
#  'bruitish': 'GB',
#  'bruttish': 'GB',
#  'btittish': 'GB',
#  'btrish': 'GB',
#  'bugaria': 'BG',
#  'bulga': 'BG',
#  'bulgarien': 'BG',
#  'burma': 'MM',
#  'burundian': 'BI',
#  'cameronnian': 'CM',
#  'camerounian': 'CM',
#  'camerronian': 'CM',
#  'camoraian': 'CM',
#  'camreoon': 'CM',
#  'canadier': 'CA',
#  'candadian': 'CA',
#  'candanian': 'CA',
#  'caucasian british': 'GB',
#  'caymanian': 'KY',
#  'central african republic (car)': 'CF',
#  'manager': 'DQ',
#  'check': 'CZ',
#  'chile': 'CL',
#  'chin': 'CN',
#  'china (mainland)': 'CN',
#  'china prc': 'CN',
#  'china, p.r.': 'CN',
#  'chinese sar': 'CN',
#  'chiness': 'CN',
#  'chinesse': 'CN',
#  'chinise': 'CN',
#  'chnese': 'CN',
#  'citizen of muritius': 'MU',
#  'citizen of republic of cyprus': 'CY',
#  'citizen of trinidad and tobago': 'TT',
#  'doctor': 'DQ',
#  'commonwealth of domi': 'DO',
#  'congelese': 'CD',
#  'cook islander': 'CK',
#  'costarican': 'CR',
#  'costarrican': 'CR',
#  'cpriot': 'CY',
#  'crotian': 'HR',
#  'crypiot': 'CY',
#  'cymraeg': 'GB',
#  'cypriat': 'CY',
#  'cyprys': 'CY',
#  'czechoslakia': 'CZ',
#  'czechoslovakia': 'CZ',
#  'damascus': 'SY',
#  'democratic republic of congo': 'CD',
#  'denish': 'DK',
#  'djiboutian': 'DJ',
#  'dominica': 'DM',
#  'dominicano': 'DO',
#  'doutch': 'NL',
#  'durch': 'NL',
#  'dutch (netherlands)': 'NL',
#  'duth': 'NL',
#  'east timorese': 'TL',
#  'egyp': 'EG',
#  'ei': 'IE',
#  'el salvador': 'SV',
#  'emglish': 'GB',
#  'enghlish': 'GB',
#  'engilish': 'GB',
#  'engineer': 'GN',
#  'engl': 'GB',
#  'englaish': 'GB',
#  'englisg': 'GB',
#  'english - british': 'GB',
#  'english-british': 'GB',
#  'englisn': 'GB',
#  'englosh': 'GB',
#  'enlish': 'GB',
#  'estionian': 'EE',
#  'estonain': 'EE',
#  'estorian': 'EE',
#  'eu cech republic': 'CZ',
#  'european british': 'GB',
#  'eygiptian': 'EG',
#  'filipina': 'PH',
#  'filipino,': 'PH',
#  'filipno': 'PH',
#  'fillipino': 'PH',
#  'fillopino': 'PH',
#  'finn': 'FI',
#  'flemish': 'BE',
#  'fremch': 'FR',
#  'frenc': 'FR',
#  'frnech': 'FR',
#  'g b': 'GB',
#  'gamban': 'GA',
#  'gb citizen': 'GB',
#  'georgia': 'GE',
#  'georgien': 'GE',
#  'georgiev': 'GE',
#  'germ': 'DE',
#  'german national': 'DE',
#  'germna': 'DE',
#  'ghahanian': 'GH',
#  'ghananian': 'GH',
#  'ghanean': 'GH',
#  'ghanese': 'GH',
#  'great britain & usa': 'GB',
#  'greeck': 'GR',
#  'greek / hellenic': 'GR',
#  'guayanese': 'GF',
#  'guinea': 'GN',
#  'guinea bissau': 'GW',
#  'guinea conakry': 'GN',
#  'guinea-bissau': 'GW',
#  'guyana': 'GY',
#  'guyanan': 'GY',
#  'haitian citizen': 'HT',
#  'haungarian': 'HU',
#  'helenic greek': 'GR',
#  'hellenic (greek)': 'GR',
#  'hk': 'HK',
#  'hksar': 'EG',
#  'hong kong national': 'HK',
#  'hrvatsko': 'HR',
#  'hunagarian': 'HR',
#  'hunagrian': 'HR',
#  'hungairan': 'HU',
#  'hungerian': 'HU',
#  'hungry': 'HU',
#  'hyngarian': 'HU',
#  'iceland': 'IS',
#  'icleland': 'IS',
#  'i-kiribati': 'KI',
#  "i'm british": 'GB',
#  'indean': 'IN',
#  'indian with ilr': 'IN',
#  'indin': 'IN',
#  'indina': 'IN',
#  'inidan': 'IN',
#  'inidian': 'IN',
#  'iraeli': 'IL',
#  'iranain': 'IR',
#  'irania': 'IR',
#  'iraqui': 'IQ',
#  'iriish': 'IE',
#  'iris': 'IE',
#  'irish national': 'IE',
#  'irish.': 'IE',
#  'isle of man': 'IM',
#  'israli': 'IL',
#  'accountant': 'DQ',
#  'italain': 'IT',
#  'italian?': 'IT',
#  'itallian': 'IT',
#  'itialian': 'IT',
#  'itlian': 'IT',
#  'ivoirienne': 'CI',
#  'jamacain': 'JM',
#  'jamacan': 'JM',
#  'jamaician': 'JM',
#  'jamaicsn': 'JM',
#  'jamiacan': 'JM',
#  'jamican': 'JM',
#  'commercial agent': 'DQ',
#  'it consultant': 'DQ',
#  'joardanian': 'JO',
#  'jordanien': 'JO',
#  'management control': 'DQ',
#  'owner': 'DQ',
#  'kazachstan': 'KZ',
#  'kazahstan': 'KZ',
#  'kenyian': 'KE',
#  'kirghiz': 'KG',
#  'kittitian': 'KN',
#  'kittitian, nevisian': 'KN',
#  'korean (south)': 'KR',
#  'kosivan': 'XK',
#  'kososvo': 'XK',
#  'kosovar': 'XK',
#  'kotri': 'DQ',
#  'kurdistan': 'TR',
#  'kyrghyz': 'KG',
#  'kyrgyztan': 'KG',
#  'latian': 'LV',
#  'leboneese': 'LB',
#  'liechtensteinerin': 'LI',
#  'lietuva': 'LT',
#  'lietuvos': 'LT',
#  'lirhuanian': 'LT',
#  'lithanian': 'LT',
#  'lithaunian': 'LT',
#  'lithhuanian': 'LT',
#  'lithiania': 'LT',
#  'lithianian': 'LT',
#  'lithiuan': 'LT',
#  'lithuainian': 'LT',
#  'lithuananian': 'LT',
#  'lithuaniam': 'LT',
#  'lithuanina': 'LT',
#  'lithuaninan': 'LT',
#  'lithuianian': 'LT',
#  'lithunanian': 'LT',
#  'lithunian': 'LT',
#  'lituania': 'LT',
#  'lituenian': 'LT',
#  'litvanian': 'LT',
#  'luthuania': 'LT',
#  'luthuanian': 'LT',
#  'luxemburgese': 'LU',
#  'macao': 'MO',
#  'malayasia': 'MY',
#  'malayasian': 'MY',
#  'malayian': 'MY',
#  'malta': 'MT',
#  ...}

# %%
pd.to_pickle(nationality_2_codes, "data/nation_map.pkl")

# %% [markdown]
# ## Storing the countries back in Neo4j
#
# Now we can create country nodes in our graph ready to connect people and companies to

# %%
from neo4j.v1 import GraphDatabase
driver = GraphDatabase.driver("bolt://10.0.0.1:7687", auth=("myusername", "mypassword"))

# %%
country_code_map = pd.read_pickle('./data/clean_country_code_map.pkl')

# %% [markdown]
# First we create a list of all the new nodes we wish to create and their associated properties. Then we can connect to the neo4j database and run a Cypher command to insert and create new nodes; we use MERGE in case we have any duplicate entries.

# %%
countryList = [{'code': k, 'name': v} for k, v in country_code_map.items()]

# %%
with driver.session() as session:
    for key, value in clean_country_map.items():
        session.run(("UNWIND {list} AS d "
                     "MERGE (c:Country {code: d.code, name: d.name})"),
                    {"list": countryList})
