# %% [markdown]
# # Loading the Officers
#
# We have a data file of officers who have a level of control over the company. We need to map these into the system to connect them to the PSC people we are aware of.

# %%
import pandas as pd
import json
from pandas.io.json import json_normalize

import blaze as bz
# Out:
# /home/ec2-user/anaconda3/lib/python3.6/site-packages/odo/backends/pandas.py:94: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access NaTType as type(pandas.NaT)
#   @convert.register((pd.Timestamp, pd.Timedelta), (pd.tslib.NaTType, type(None)))

# %% [markdown]
# First load some sample data and do some tidying up so we don't waste RAM.

# %%
master_path = './data/'

# %%
sample_df = pd.read_csv(master_path+'officers.csv', nrows=10000)

# %%
sample_df.columns
# Out:
# Index(['id', 'company_number', 'jurisdiction_code', 'name', 'title',
#        'first_name', 'last_name', 'position', 'start_date', 'person_number',
#        'person_uid', 'end_date', 'current_status', 'occupation', 'nationality',
#        'country_of_residence', 'partial_date_of_birth', 'type',
#        'address.in_full', 'address.street_address', 'address.locality',
#        'address.region', 'address.postal_code', 'address.country',
#        'retrieved_at', 'source_url'],
#       dtype='object')

# %%
sample_df[sample_df.end_date.isnull()].iloc[0]
# Out:
# id                                                                201499282
# company_number                                                     05957738
# jurisdiction_code                                                        gb
# name                                                      DAVID IAN BROMLEY
# title                                                                    MR
# first_name                                                        DAVID IAN
# last_name                                                           BROMLEY
# position                                                           director
# start_date                                                       2010-10-01
# person_number                                                  115947850001
# person_uid                                                         11594785
# end_date                                                                NaN
# current_status                                                          NaN
# occupation                                                         DIRECTOR
# nationality                                                         BRITISH
# country_of_residence                                         UNITED KINGDOM
# partial_date_of_birth                                               1970-05
# type                                                                 Person
# address.in_full           40 LEA MANOR DRIVE\nPENN, WOLVERHAMPTON, WEST ...
# address.street_address                             40 LEA MANOR DRIVE\nPENN
# address.locality                                              WOLVERHAMPTON
# address.region                                                WEST MIDLANDS
# address.postal_code                                                 WV4 5PJ
# address.country                                              UNITED KINGDOM
# retrieved_at                                        2015-12-04 00:00:00 UTC
# source_url                https://beta.companieshouse.gov.uk/company/059...
# Name: 1, dtype: object

# %%
sample_df[sample_df.type == 'Person'].head()
# Out:
#           id company_number jurisdiction_code                        name  \
# 1  201499282       05957738                gb           DAVID IAN BROMLEY
# 2  201499298       05957738                gb           DAVID IAN BROMLEY
# 3  201499319       05957738                gb  SALLY-ANN MICHELLE BROMLEY
# 4  201499336       05957738                gb            ELIZABETH DAVIES
# 9  190421889       04066366                gb   RAZAHUSSEIN LALJI MAMDANI
#
#   title          first_name last_name  position  start_date  person_number  \
# 1    MR           DAVID IAN   BROMLEY  director  2010-10-01   115947850001
# 2    MR           DAVID IAN   BROMLEY  director  2006-10-05   115947850001
# 3   MRS  SALLY-ANN MICHELLE   BROMLEY  director  2012-12-21   121484190003
# 4    MS           ELIZABETH    DAVIES  director  2006-10-05   115947860002
# 9    MR   RAZAHUSSEIN LALJI   MAMDANI  director  2011-08-15    71984350001
#
#                          ...                          partial_date_of_birth  \
# 1                        ...                                        1970-05
# 2                        ...                                        1970-05
# 3                        ...                                        1966-08
# 4                        ...                                        1962-01
# 9                        ...                                        1947-07
#
#      type                                    address.in_full  \
# 1  Person  40 LEA MANOR DRIVE\nPENN, WOLVERHAMPTON, WEST ...
# 2  Person         40 LEA MANOR DRIVE, WOLVERHAMPTON, WV4 5PJ
# 3  Person  PENYCASTELL FARM BRYN, PORT TALBOT, WEST GLAMO...
# 4  Person  12 PONTYMASON RISE\nROGERSTONE, NEWPORT, GWENT...
# 9  Person  PREMIER SUITE, 4 CHURCHILL COURT\n58 STATION R...
#
#                               address.street_address address.locality  \
# 1                           40 LEA MANOR DRIVE\nPENN    WOLVERHAMPTON
# 2                                 40 LEA MANOR DRIVE    WOLVERHAMPTON
# 3                              PENYCASTELL FARM BRYN      PORT TALBOT
# 4                     12 PONTYMASON RISE\nROGERSTONE          NEWPORT
# 9  PREMIER SUITE, 4 CHURCHILL COURT\n58 STATION ROAD     NORTH HARROW
#
#    address.region address.postal_code address.country  \
# 1   WEST MIDLANDS             WV4 5PJ  UNITED KINGDOM
# 2             NaN             WV4 5PJ             NaN
# 3  WEST GLAMORGAN            SA13 2PY             NaN
# 4           GWENT            NP10 9GJ             NaN
# 9       MIDDLESEX             HA2 7ST             NaN
#
#               retrieved_at                                         source_url
# 1  2015-12-04 00:00:00 UTC  https://beta.companieshouse.gov.uk/company/059...
# 2  2015-12-04 00:00:00 UTC  https://beta.companieshouse.gov.uk/company/059...
# 3  2015-12-04 00:00:00 UTC  https://beta.companieshouse.gov.uk/company/059...
# 4  2015-12-04 00:00:00 UTC  https://beta.companieshouse.gov.uk/company/059...
# 9  2015-12-04 00:00:00 UTC  https://beta.companieshouse.gov.uk/company/040...
#
# [5 rows x 26 columns]

# %%
sample_df[sample_df.title.isnull()]
# Out:
#              id company_number jurisdiction_code  \
# 0     201499267       05957738                gb
# 5     190421841       04066366                gb
# 6     190421851       04066366                gb
# 7     190421865       04066366                gb
# 8     190421877       04066366                gb
# 11    207362364       05438136                gb
# 14    207362418       05438136                gb
# 16    212181681       SC322354                gb
# 17    212181694       SC322354                gb
# 18    205069123       05149111                gb
# 19    205069138       05149111                gb
# 20    205069156       05149111                gb
# 21    205069167       05149111                gb
# 22    205069187       05149111                gb
# 23    205069203       05149111                gb
# 24    205069220       05149111                gb
# 33    205069370       05149111                gb
# 34    205069386       05149111                gb
# 35    205069404       05149111                gb
# 37    205069440       05149111                gb
# 39    205069472       05149111                gb
# 40    205069489       05149111                gb
# 41    205069514       05149111                gb
# 43    205069549       05149111                gb
# 51    205069688       05149111                gb
# 55    205069751       05149111                gb
# 56    205069768       05149111                gb
# 58    235069318       05149111                gb
# 59    188647611       04264801                gb
# 60    188647622       04264801                gb
# ...         ...            ...               ...
# 9945  201276478       06358334                gb
# 9946  193030665       05564976                gb
# 9947  193030686       05564976                gb
# 9949  207171056       06783554                gb
# 9951  207171089       06783554                gb
# 9952  207619176       06244841                gb
# 9953  207619194       06244841                gb
# 9954  207619205       06244841                gb
# 9955  206963235       04381685                gb
# 9956  206963254       04381685                gb
# 9960  211204869       05557478                gb
# 9962  211204900       05557478                gb
# 9964  184200209       05522911                gb
# 9965  184200226       05522911                gb
# 9967  184200263       05522911                gb
# 9968  184200277       05522911                gb
# 9969  204690059       06012183                gb
# 9970  204690081       06012183                gb
# 9971  204690093       06012183                gb
# 9972  204690105       06012183                gb
# 9973  212588593       06125942                gb
# 9974  212588609       06125942                gb
# 9975  212588621       06125942                gb
# 9983  207819187       05514579                gb
# 9984  207819209       05514579                gb
# 9986  195700316       06307539                gb
# 9988  195700344       06307539                gb
# 9993  192495760       03636679                gb
# 9997  192495830       03636679                gb
# 9999   53288738       07375066                gb
#
#                                                    name title  \
# 0                                 PHOENIX AUDIT LIMITED   NaN
# 5                                  FATBRAIN.COM LIMITED   NaN
# 6                             FIRST SECRETARIES LIMITED   NaN
# 7                                     A COMPANY LIMITED   NaN
# 8                               FIRST DIRECTORS LIMITED   NaN
# 11                      INCORPORATE SECRETARIAT LIMITED   NaN
# 14                        INCORPORATE DIRECTORS LIMITED   NaN
# 16                            PATRICIA ELIZABETH BUTLER   NaN
# 17                                        THOMAS BUTLER   NaN
# 18            CLIFFORD CHANCE SECRETARIES (CCA) LIMITED   NaN
# 19                  CLIFFORD CHANCE SECRETARIES LIMITED   NaN
# 20                                          JOHN DAVIES   NaN
# 21                                      VICTORIA HAYNES   NaN
# 22                                   MARK FALCON MILLAR   NaN
# 23                                     TAGUMA NGONDONGA   NaN
# 24                                   ROBERT JAMES SCOTT   NaN
# 33                                  DEREK JAMES ELLIOTT   NaN
# 34                                 JOHN ANDREW GOODSELL   NaN
# 35                                 NICHOLAS JOHN HEWITT   NaN
# 37                                 ROBIN PEVERIL HOOPER   NaN
# 39                      CHRISTOPHER TREVOR PETER JANSEN   NaN
# 40                                JONATHAN RUSSELL KAYE   NaN
# 41                                MATTHEW ROBERT LAYTON   NaN
# 43                                 ROBERT RICHARD LUCAS   NaN
# 51                                     DAVID JOHN PUDGE   NaN
# 55                             SUZANNE DOROTHY WILLIAMS   NaN
# 56                                    PAUL ANTONY WOOLF   NaN
# 58                                      VICTORIA HAYNES   NaN
# 59                    OCS CORPORATE SECRETARIES LIMITED   NaN
# 60                                ANN DAPHNE RICHARDSON   NaN
# ...                                                 ...   ...
# 9945                                        ANDREW LANE   NaN
# 9946                                     AMANDA PILLING   NaN
# 9947                                     ADRIAN PILLING   NaN
# 9949                                    ANDREA NICOLAOU   NaN
# 9951                                      ANDREAS KOIZI   NaN
# 9952  SECSERVICE24 ADMINISTRATION & MANAGEMENT UK LI...   NaN
# 9953                                     GUENTER PLEYER   NaN
# 9954                                      JOERG SCHMIDT   NaN
# 9955                                     SUZANNE BREWER   NaN
# 9956                                ALLISON JANE DAVIES   NaN
# 9960                      M W DOUGLAS & COMPANY LIMITED   NaN
# 9962                           DOUGLAS NOMINEES LIMITED   NaN
# 9964                            MARIA CHRISTINE BRISTOW   NaN
# 9965                         TEMPLE SECRETARIES LIMITED   NaN
# 9967                          COMPANY DIRECTORS LIMITED   NaN
# 9968                                 MARK DAVID JACKSON   NaN
# 9969                                      SIKANDAR AYUB   NaN
# 9970                         FORM 10 SECRETARIES FD LTD   NaN
# 9971                                      MOHAMMAD AYUB   NaN
# 9972                           FORM 10 DIRECTORS FD LTD   NaN
# 9973                           GO AHEAD SERVICE LIMITED   NaN
# 9974                                  ALEXANDER DUBOVOY   NaN
# 9975                                   ANDREAS ORTMEYER   NaN
# 9983      STEINBERG & PARTNERS BUSINESS CONSULTING CORP   NaN
# 9984                                      RICHARD ABELE   NaN
# 9986                           ANNE-MARIE JARNELL-JONES   NaN
# 9988                           ANNE-MARIE JARNELL-JONES   NaN
# 9993                     LONDON LAW SECRETARIAL LIMITED   NaN
# 9997                        LONDON LAW SERVICES LIMITED   NaN
# 9999                                     ANTHONY LESLIE   NaN
#
#                     first_name  \
# 0                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 11                         NaN
# 14                         NaN
# 16          PATRICIA ELIZABETH
# 17                      THOMAS
# 18                         NaN
# 19                         NaN
# 20                        JOHN
# 21                    VICTORIA
# 22                 MARK FALCON
# 23                      TAGUMA
# 24                ROBERT JAMES
# 33                 DEREK JAMES
# 34                 JOHN ANDREW
# 35               NICHOLAS JOHN
# 37               ROBIN PEVERIL
# 39    CHRISTOPHER TREVOR PETER
# 40            JONATHAN RUSSELL
# 41              MATTHEW ROBERT
# 43              ROBERT RICHARD
# 51                  DAVID JOHN
# 55             SUZANNE DOROTHY
# 56                 PAUL ANTONY
# 58                    VICTORIA
# 59                         NaN
# 60                  ANN DAPHNE
# ...                        ...
# 9945                    ANDREW
# 9946                    AMANDA
# 9947                    ADRIAN
# 9949                    ANDREA
# 9951                   ANDREAS
# 9952                       NaN
# 9953                   GUENTER
# 9954                     JOERG
# 9955                   SUZANNE
# 9956              ALLISON JANE
# 9960                       NaN
# 9962                       NaN
# 9964           MARIA CHRISTINE
# 9965                       NaN
# 9967                       NaN
# 9968                MARK DAVID
# 9969                  SIKANDAR
# 9970                       NaN
# 9971                  MOHAMMAD
# 9972                       NaN
# 9973                       NaN
# 9974                 ALEXANDER
# 9975                   ANDREAS
# 9983                       NaN
# 9984                   RICHARD
# 9986                ANNE-MARIE
# 9988                ANNE-MARIE
# 9993                       NaN
# 9997                       NaN
# 9999                   ANTHONY
#
#                                               last_name   position  \
# 0                                 PHOENIX AUDIT LIMITED  secretary
# 5                                  FATBRAIN.COM LIMITED  secretary
# 6                             FIRST SECRETARIES LIMITED  secretary
# 7                                    +A COMPANY LIMITED   director
# 8                               FIRST DIRECTORS LIMITED   director
# 11                      INCORPORATE SECRETARIAT LIMITED  secretary
# 14                        INCORPORATE DIRECTORS LIMITED   director
# 16                                               BUTLER  secretary
# 17                                               BUTLER   director
# 18            CLIFFORD CHANCE SECRETARIES (CCA) LIMITED  secretary
# 19                  CLIFFORD CHANCE SECRETARIES LIMITED  secretary
# 20                                               DAVIES  secretary
# 21                                               HAYNES  secretary
# 22                                               MILLAR  secretary
# 23                                            NGONDONGA  secretary
# 24                                                SCOTT  secretary
# 33                                              ELLIOTT   director
# 34                                             GOODSELL   director
# 35                                               HEWITT   director
# 37                                               HOOPER   director
# 39                                               JANSEN   director
# 40                                                 KAYE   director
# 41                                               LAYTON   director
# 43                                                LUCAS   director
# 51                                                PUDGE   director
# 55                                             WILLIAMS   director
# 56                                                WOOLF   director
# 58                                               HAYNES  secretary
# 59                    OCS CORPORATE SECRETARIES LIMITED  secretary
# 60                                           RICHARDSON  secretary
# ...                                                 ...        ...
# 9945                                               LANE   director
# 9946                                            PILLING  secretary
# 9947                                            PILLING   director
# 9949                                           NICOLAOU  secretary
# 9951                                              KOIZI   director
# 9952  SECSERVICE24 ADMINISTRATION & MANAGEMENT UK LI...  secretary
          ...
# 16                          ...
# 17                          ...
# 18                          ...
# 19                          ...
# 20                          ...
# 21                          ...
# 22                          ...
# 23                          ...
# 24                          ...
# 33                          ...
# 34                          ...
# 35                          ...
# 37                          ...
# 39                          ...
# 40                          ...
# 41                          ...
# 43                          ...
# 51                          ...
# 55                          ...
# 56                          ...
# 58                          ...
# 59                          ...
# 60                          ...
# ...                         ...
# 9945                        ...
# 9946                        ...
# 9947                        ...
# 9949                        ...
# 9951                        ...
# 9952                        ...
# 9953                        ...
# 9954                        ...
# 9955                        ...
# 9956                        ...
# 9960                        ...
# 9962                        ...
# 9964                        ...
# 9965                        ...
# 9967                        ...
# 9968                        ...
# 9969                        ...
# 9970                        ...
# 9971                        ...
# 9972                        ...
# 9973                        ...
# 9974                        ...
# 9975                        ...
# 9983                        ...
# 9984                        ...
# 9986                        ...
# 9988                        ...
# 9993                        ...
# 9997                        ...
# 9999                        ...
#
#       partial_date_of_birth     type  \
# 0                       NaN  Company
# 5                       NaN  Company
# 6                       NaN  Company
# 7                       NaN  Company
# 8                   1989-08  Company
# 11                      NaN  Company
# 14                      NaN  Company
# 16                  1960-08   Person
# 17                  1961-07   Person
# 18                      NaN  Company
# 19                      NaN  Company
# 20                  1960-02   Person
# 21                      NaN   Person
# 22                      NaN   Person
# 23                      NaN   Person
# 24                      NaN   Person
# 33                  1969-02   Person
# 34                  1959-01   Person
# 35                  1962-03   Person
# 37                  1973-07   Person
# 39                  1970-07   Person
# 40                  1973-01   Person
# 41                  1961-02   Person
# 43                  1962-08   Person
# 51                  1965-08   Person
# 55                  1967-09   Person
# 56                  1964-12   Person
# 58                  1973-01   Person
# 59                      NaN  Company
# 60                  1942-03   Person
# ...                     ...      ...
# 9945                1965-09   Person
# 9946                    NaN   Person
# 9947                1966-09   Person
# 9949                    NaN   Person
# 9951                1964-04   Person
# 9952                    NaN  Company
# 9953                1940-12   Person
# 9954                1943-03   Person
# 9955                    NaN   Person
# 9956                    NaN   Person
# 9960                    NaN  Company
# 9962                    NaN  Company
# 9964                    NaN   Person
# 9965                    NaN  Company
# 9967                    NaN  Company
# 9968                1968-12   Person
# 9969                1987-11   Person
# 9970                    NaN  Company
# 9971                1962-08   Person
# 9972                    NaN  Company
# 9973                    NaN  Company
# 9974                1974-01   Person
# 9975                1967-06   Person
# 9983                    NaN  Company
# 9984                1953-03   Person
# 9986                1971-08   Person
# 9988                1971-08   Person
# 9993                    NaN  Company
# 9997                    NaN  Company
# 9999                1964-12   Person
#
#                                         address.in_full  \
# 0      35 OXFORD STREET\nPONTYCYMER, BRIDGEND, CF32 8DD
# 5     PREMIER SUITE 4 CHURCHILL COURT\n58 STATION RO...
# 6                   72 NEW BOND STREET, LONDON, W1S 1RR
# 7     PREMIER SUITE 4 CHURCHILL COURT\n58 STATION RO...
# 8                   72 NEW BOND STREET, LONDON, W1S 1RR
# 11    4TH FLOOR 3 TENTERDEN STREET\nHANOVER SQUARE, ...
# 14    4TH FLOOR, 3 TENTERDEN STREET\nHANOVER SQUARE,...
# 16    8 BERNISDALE GARDENS\nDRUMCHAPEL, GLASGOW, LAN...
# 17    8 BERNISDALE GARDENS, GLASGOW, STRATHCLYDE, G1...
# 18                10 UPPER BANK STREET, LONDON, E14 5JJ
# 19                10 UPPER BANK STREET, LONDON, E14 5JJ
# 20    ENBROOK PARK SANDGATE, FOLKESTONE, KENT, CT20 ...
# 21    ENBROOK PARK SANDGATE, FOLKESTONE, KENT, CT20 ...
# 22    FANUM HOUSE BASING VIEW\nBASINGSTOKE, HANTS, R...
# 23    FANUM HOUSE BASING VIEW, BASINGSTOKE, HAMPSHIR...
# 24    FANUM HOUSE BASING VIEW, BASINGSTOKE, HAMPSHIR...
# 33      50 WILTON CRESCENT\nWIMBLEDON, LONDON, SW19 3QS
# 34           1 ENBROOK PARK, FOLKESTONE, KENT, CT20 3SE
# 35    FANUM HOUSE BASING VIEW, BASINGSTOKE, HAMPSHIR...
# 37                    18 BEAUCLERC ROAD, LONDON, W6 0NS
# 39    FANUM HOUSE BASING VIEW, BASINGSTOKE, HAMPSHIR...
# 40                  13 KELMSCOTT ROAD, LONDON, SW11 6QX
# 41    FLAT 49 8 NEW CRANE WHARF\nNEW CRANE PLACE, LO...
# 43    THE FORGE\nAYOT ST. LAWRENCE, WELWYN, HERTFORD...
# 51                20 HERONDALE AVENUE, LONDON, SW18 3JL
# 55    FANUM HOUSE\nBASING VIEW, BASINGSTOKE, HAMPSHI...
# 56                      18 FAIRFAX ROAD, LONDON, W4 1EW
# 58    ENBROOK PARK SANDGATE, FOLKESTONE, KENT, CT20 ...
# 59    MINSHULL HOUSE 67 WELLINGTON ROAD NORTH, STOCK...
# 60    CHURCHILL HOUSE\nFURNERS MEAD, HENFIELD, WEST ...
# ...                                                 ...
# 9945  256 ACKLAM ROAD, MIDDLESBROUGH, CLEVELAND, TS5...
# 9946  18 CHURCH LANE\nWRIGHTINGTON, WIGAN, LANCASHIR...
# 9947  18 CHURCH LANE\nWRIGHTINGTON, WIGAN, LANCASHIR...
# 9949     27 MANDEVILLE ROAD\nSOUTHGATE, LONDON, N14 7NJ
# 9951        53 VICTORIA ROAD\nEDMONTON, LONDON, N18 2UG
# 9952  THE MERIDIAN\n4 COPTHALL HOUSE, STATION SQUARE...
# 9953  SPIELMANNSTR. 18, FRANKFURT AM MAIN, D65934, G...
# 9954  ALT GRIESHEIM 19, FRANKFURT AM MAIN, D65933, G...
# 9955  SOMERSET HOUSE\n40-49 PRICE STREET, BIRMINGHAM...
# 9956  CRANNMOOR FARM WROTTESLEY PARK ROAD\nWROTTESLE...
# 9960    REGENT HOUSE\n316 BEULAH HILL, LONDON, SE19 3HP
# 9962    REGENT HOUSE\n316 BEULAH HILL, LONDON, SE19 3HF
# 9964  GREENTOPS\nHEADCORN ROAD SUTTON VALENCE, MAIDS...
# 9965            788-790 FINCHLEY ROAD, LONDON, NW11 7TJ
# 9967            788-790 FINCHLEY ROAD, LONDON, NW11 7TJ
# 9968  12 STILEBRIDGE LANE\nMARDEN, TONBRIDGE, KENT, ...
# 9969  28 SELBOURNE AVENUE, DEWSBURY, WEST YORKSHIRE,...
# 9970    39A LEICESTER ROAD\nSALFORD, MANCHESTER, M7 4AS
# 9971  28 SELBOURNE AVENUE, DEWSBURY, WEST YORKSHIRE,...
# 9972    39A LEICESTER ROAD\nSALFORD, MANCHESTER, M7 4AS
# 9973  69 GREAT HAMPTON STREET, BIRMINGHAM, WEST MIDL...
# 9974         OSTPREUSENSTR.98, METTMANN, 40822, GERMANY
# 9975                MOORSTR. 260, 48432 RHEINE, GERMANY
# 9983          SUITE 3\n95 WILTON ROAD, LONDON, SW1V 1BZ
# 9984     KRAEMERSTRASSE 17, LUDWIGSBURG, 71642, GERMANY
# 9986  7 BLACKFRIARS, YARM ON TEES, NORTH YORKSHIRE, ...
# 9988  7 BLACKFRIARS, YARM ON TEES, NORTH YORKSHIRE, ...
# 9993  84 TEMPLE CHAMBERS\nTEMPLE AVENUE, LONDON, EC4...
# 9997  84 TEMPLE CHAMBERS\nTEMPLE AVENUE, LONDON, EC4...
# 9999  THE HAWTHORNS GREEN MEADOWS\nHOM GREEN, ROSS-O...
#
#                                  address.street_address   address.locality  \
# 0                          35 OXFORD STREET\nPONTYCYMER           BRIDGEND
# 5      PREMIER SUITE 4 CHURCHILL COURT\n58 STATION ROAD       NORTH HARROW
# 6                                    72 NEW BOND STREET             LONDON
# 7      PREMIER SUITE 4 CHURCHILL COURT\n58 STATION ROAD       NORTH HARROW
# 8                                    72 NEW BOND STREET             LONDON
# 11         4TH FLOOR 3 TENTERDEN STREET\nHANOVER SQUARE             LONDON
# 14        4TH FLOOR, 3 TENTERDEN STREET\nHANOVER SQUARE             LONDON
# 16                     8 BERNISDALE GARDENS\nDRUMCHAPEL            GLASGOW
# 17                                 8 BERNISDALE GARDENS            GLASGOW
# 18                                 10 UPPER BANK STREET             LONDON
# 19                                 10 UPPER BANK STREET             LONDON
# 20                                ENBROOK PARK SANDGATE         FOLKESTONE
# 21                                ENBROOK PARK SANDGATE         FOLKESTONE
# 22                 FANUM HOUSE BASING VIEW\nBASINGSTOKE              HANTS
# 23                              FANUM HOUSE BASING VIEW        BASINGSTOKE
# 24                              FANUM HOUSE BASING VIEW        BASINGSTOKE
# 33                        50 WILTON CRESCENT\nWIMBLEDON             LONDON
# 34                                       1 ENBROOK PARK         FOLKESTONE
# 35                              FANUM HOUSE BASING VIEW        BASINGSTOKE
# 37                                    18 BEAUCLERC ROAD             LONDON
# 39                              FANUM HOUSE BASING VIEW        BASINGSTOKE
# 40                                    13 KELMSCOTT ROAD             LONDON
# 41           FLAT 49 8 NEW CRANE WHARF\nNEW CRANE PLACE             LONDON
# 43                         THE FORGE\nAYOT ST. LAWRENCE             WELWYN
# 51                                  20 HERONDALE AVENUE             LONDON
# 55                             FANUM HOUSE\nBASING VIEW        BASINGSTOKE
# 56                                      18 FAIRFAX ROAD             LONDON
# 58                                ENBROOK PARK SANDGATE         FOLKESTONE
# 59              MINSHULL HOUSE 67 WELLINGTON ROAD NORTH          STOCKPORT
# 60                        CHURCHILL HOUSE\nFURNERS MEAD           HENFIELD
# ...                                                 ...                ...
# 9945                                    256 ACKLAM ROAD      MIDDLESBROUGH
# 9946                       18 CHURCH LANE\nWRIGHTINGTON              WIGAN
# 9947                       18 CHURCH LANE\nWRIGHTINGTON              WIGAN
# 9949                      27 MANDEVILLE ROAD\nSOUTHGATE             LONDON
# 9951                         53 VICTORIA ROAD\nEDMONTON             LONDON
# 9952     THE MERIDIAN\n4 COPTHALL HOUSE, STATION SQUARE           COVENTRY
# 9953                                   SPIELMANNSTR. 18  FRANKFURT AM MAIN
# 9954                                   ALT GRIESHEIM 19  FRANKFURT AM MAIN
# 9955                 SOMERSET HOUSE\n40-49 PRICE STREET         BIRMINGHAM
# 9956  CRANNMOOR FARM WROTTESLEY PARK ROAD\nWROTTESLE...      WOLVERHAMPTON
# 9960                      REGENT HOUSE\n316 BEULAH HILL             LONDON
# 9962                      REGENT HOUSE\n316 BEULAH HILL             LONDON
# 9964            GREENTOPS\nHEADCORN ROAD SUTTON VALENCE          MAIDSTONE
# 9965                              788-790 FINCHLEY ROAD             LONDON
# 9967                              788-790 FINCHLEY ROAD             LONDON
# 9968                        12 STILEBRIDGE LANE\nMARDEN          TONBRIDGE
# 9969                                28 SELBOURNE AVENUE           DEWSBURY
# 9970                        39A LEICESTER ROAD\nSALFORD         MANCHESTER
# 9971                                28 SELBOURNE AVENUE           DEWSBURY
# 9972                        39A LEICESTER ROAD\nSALFORD         MANCHESTER
# 9973                            69 GREAT HAMPTON STREET         BIRMINGHAM
# 9974                                   OSTPREUSENSTR.98           METTMANN
# 9975                                       MOORSTR. 260       48432 RHEINE
# 9983                            SUITE 3\n95 WILTON ROAD             LONDON
# 9984                                  KRAEMERSTRASSE 17        LUDWIGSBURG
# 9986                                      7 BLACKFRIARS       YARM ON TEES
# 9988                                      7 BLACKFRIARS       YARM ON TEES
# 9993                  84 TEMPLE CHAMBERS\nTEMPLE AVENUE             LONDON
# 9997                  84 TEMPLE CHAMBERS\nTEMPLE AVENUE             LONDON
# 9999             THE HAWTHORNS GREEN MEADOWS\nHOM GREEN        ROSS-ON-WYE
#
#        address.region address.postal_code address.country  \
# 0                 NaN            CF32 8DD             NaN
# 5           MIDDLESEX             HA2 7ST  UNITED KINGDOM
# 6                 NaN             W1S 1RR             NaN
# 7           MIDDLESEX             HA2 7ST             NaN
# 8                 NaN             W1S 1RR             NaN
# 11                NaN             W1S 1TD             NaN
# 14                NaN             W1S 1TD             NaN
# 16        LANARKSHIRE             G15 8BU             NaN
# 17        STRATHCLYDE             G15 8BU             NaN
# 18                NaN             E14 5JJ             NaN
# 19                NaN             E14 5JJ             NaN
# 20               KENT            CT20 3SE  UNITED KINGDOM
# 21               KENT            CT20 3SE  UNITED KINGDOM
# 22                NaN            RG21 4EA  UNITED KINGDOM
# 23          HAMPSHIRE            RG21 4EA  UNITED KINGDOM
# 24          HAMPSHIRE            RG21 4EA  UNITED KINGDOM
# 33                NaN            SW19 3QS             NaN
# 34               KENT            CT20 3SE             NaN
# 35          HAMPSHIRE            RG21 4EA  UNITED KINGDOM
# 37                NaN              W6 0NS             NaN
# 39          HAMPSHIRE            RG21 4EA  UNITED KINGDOM
# 40                NaN            SW11 6QX             NaN
# 41                NaN             E1W 3TX             NaN
# 43      HERTFORDSHIRE             AL6 9BW             NaN
# 51                NaN            SW18 3JL             NaN
# 55          HAMPSHIRE            RG21 4EA             NaN
# 56                NaN              W4 1EW             NaN
# 58               KENT            CT20 3SE  UNITED KINGDOM
# 9962  https://beta.companieshouse.gov.uk/company/055...
# 9964  https://beta.companieshouse.gov.uk/company/055...
# 9965  https://beta.companieshouse.gov.uk/company/055...
# 9967  https://beta.companieshouse.gov.uk/company/055...
# 9968  https://beta.companieshouse.gov.uk/company/055...
# 9969  https://beta.companieshouse.gov.uk/company/060...
# 9970  https://beta.companieshouse.gov.uk/company/060...
# 9971  https://beta.companieshouse.gov.uk/company/060...
# 9972  https://beta.companieshouse.gov.uk/company/060...
# 9973  https://beta.companieshouse.gov.uk/company/061...
# 9974  https://beta.companieshouse.gov.uk/company/061...
# 9975  https://beta.companieshouse.gov.uk/company/061...
# 9983  https://beta.companieshouse.gov.uk/company/055...
# 9984  https://beta.companieshouse.gov.uk/company/055...
# 9986  https://beta.companieshouse.gov.uk/company/063...
# 9988  https://beta.companieshouse.gov.uk/company/063...
# 9993  https://beta.companieshouse.gov.uk/company/036...
# 9997  https://beta.companieshouse.gov.uk/company/036...
# 9999  https://beta.companieshouse.gov.uk/company/073...
#
# [5897 rows x 26 columns]

# %% [markdown]
# From this and further exploring the data there are two "types" of officer in the data; people and companies.
#
# We will start with how to map People officers into the database. We will also ignore officers who have an "end date" as they are no longer actively connected to the company.
#
# ## People who are officers
#
# First we will define a number of functions that can map the data into the node objects that we want to hold for people who are officers.

# %%
def officer_dob(record):
    "Function to create dob string identifier for person"
    record.fillna('')
    data = record['partial_date_of_birth']
    try:
        year, month = data.split('-')
        dob_segment = "{}/{}".format(str(month).zfill(2), year)
        return dob_segment
    except (AttributeError, TypeError, ValueError) as e:
        return '00/0000'

def officer_name_id(record):
    "Function to create name string identifier for person"
    fullname = record['name'].split()
    data = {
        'first_name': fullname[0],
        'last_name': record['last_name'],
        'middle_name': ' '.join(fullname[1:-1])
    }
    try:
        name_segment = "{}_{}_{}".format(data.get('last_name', '').upper(), 
                                         data.get('middle_name', '').lower(),
                                         data.get('first_name', '').lower())
        return name_segment.replace(' ', '-')
    except TypeError as e:
        return 'NONAME__BLANK'
    except AttributeError:
        return 'NONAME__BLANK'
    
def officer_uid(record):
    "Function to create a unique ID for someone from their name and dob"
    components = [officer_name_id(record), officer_dob(record)]
    return {'uid': ':'.join(components)}

def officer_name(record):
    "Function to create name record of person"
    fullname = record['name'].split()
    data = {
        'forename': fullname[0].title(),
        'surname': record['last_name'].title(),
        'middle_name': ' '.join(fullname[1:-1]).title(),
        'title': record['title'].title(),
        'name': ' '.join([record['title'], record['name']])
    }    
    try:
        name_record = {
            'surname': data.get('surname', ''),
            'middle_name': data.get('middle_name', ''),
            'forename': data.get('forename', ''),
            'title': data.get('title', ''),
            'name': data.get('name', '').upper()
        }
        return name_record
    except TypeError as e:
        return {}
    except AttributeError:
        return {}

def officer_address(record):
    "Function to create a address details for person"
    record.fillna('', inplace=True)
    address = record['address.street_address'].split('\\n')
    address_Line1 = address[0]
    address_Line2 = ''
    if len(address)>1:
        address_Line2 = address[1]

    data = {
        'address_line_1': address_Line1,
        'address_line_2': address_Line2,
        'locality': record['address.locality'],
        'region': record['address.region'],
        'postal_code': record['address.postal_code'],
        'country': record['address.country']
    }
    try:
        new_address = {
            'address_Line1': data.get('address_line_1', ''),
            'address_Line2': data.get('address_line_2', ''),
            'address_PostTown': data.get('locality', '').upper(),
            'address_POBox': data.get('po_box', ''),
            'address_County': data.get('region', '').upper(),
            'address_PostCode': data.get('postal_code', '').upper(),
            'address_Country': data.get('country', '').upper(),
            'address_InFull': record['address.in_full']
        }
        return new_address
    except TypeError as e:
        return {'address_Country': "UNKNOWN"}
    except AttributeError:
        return {'address_Country': "UNKNOWN"}
    
def officer_details(record):
    "Function to create a relationship details for person"
    details = {}
    details['company_id'] = str(record['company_number'])
    details['officer_kind'] = record['position'].upper()
    details['nationality'] = record['nationality']
    details['ceased_on'] = record['end_date']
    details['source_url'] = record['source_url']
    details['country_of_residence'] = record['country_of_residence']
    details['person_uid'] = str(record['person_uid'])
    dob = record['partial_date_of_birth']
    try:
        year, month = dob.split('-')
        details['DOB'] = "{}/{}".format(str(month).zfill(2), year)
    except (TypeError, ValueError) as e:
        pass
    return details
    

def new_officer_record(record):
    "Function to create a new record that is flat"
    uid = officer_uid(record)
    address = officer_address(record)
    return {**uid, **address, 
            **officer_details(record), 
            **officer_name(record)}

# %%
sample_df[sample_df.type == 'Person'].apply(new_officer_record, axis=1).iloc[2]
# Out:
# {'DOB': '08/1966',
#  'address_Country': '',
#  'address_County': 'WEST GLAMORGAN',
#  'address_InFull': 'PENYCASTELL FARM BRYN, PORT TALBOT, WEST GLAMORGAN, SA13 2PY',
#  'address_Line1': 'PENYCASTELL FARM BRYN',
#  'address_Line2': '',
#  'address_POBox': '',
#  'address_PostCode': 'SA13 2PY',
#  'address_PostTown': 'PORT TALBOT',
#  'ceased_on': '',
#  'company_id': '05957738',
#  'country_of_residence': 'ENGLAND',
#  'forename': 'Sally-Ann',
#  'middle_name': 'Michelle',
#  'name': 'MRS SALLY-ANN MICHELLE BROMLEY',
#  'nationality': 'BRITISH',
#  'officer_kind': 'DIRECTOR',
#  'person_uid': '12148419',
#  'source_url': 'https://beta.companieshouse.gov.uk/company/05957738',
#  'surname': 'Bromley',
#  'title': 'Mrs',
#  'uid': 'BROMLEY_michelle_sally-ann:08/1966'}

# %% [markdown]
# We will use the reference objects that we have built before to know how to map countries and nationalities

# %%
country_code_map = pd.read_pickle('./data/clean_country_code_map.pkl')
combined_map = pd.read_pickle('./data/combined_country_map.pkl')
nationality_map = pd.read_pickle('./data/nation_map.pkl')

# %% [markdown]
# Let's wrap up our processing data into a function that can act on an input dataframe object

# %%
def officer_etl(original_df):
    original_df = original_df[original_df.type == 'Person']
    original_df = original_df[original_df.end_date.isnull()]
    processed_df = original_df.apply(lambda s: pd.Series(new_officer_record(s)), axis=1)
    processed_df['Citizen_of'] = processed_df.nationality.apply(lambda x: nationality_map.get(x.lower(), ''))
    processed_df['Registered_in'] = processed_df.address_Country.apply(lambda x: combined_map.get(x.lower(), ''))
    processed_df['Resident_in'] = processed_df.country_of_residence.apply(lambda x: combined_map.get(x.lower(), ''))
    input_data = [v for k,v in processed_df.T.to_dict().items()]
    return input_data

# %% [markdown]
# Example test of action a sample of the data

# %%
test = officer_etl(sample_df.head(20))
print(len(test))
print(test[0])
# Out:
# 8
# {'DOB': '05/1970', 'address_Country': 'UNITED KINGDOM', 'address_County': 'WEST MIDLANDS', 'address_InFull': '40 LEA MANOR DRIVE\\nPENN, WOLVERHAMPTON, WEST MIDLANDS, WV4 5PJ, UNITED KINGDOM', 'address_Line1': '40 LEA MANOR DRIVE', 'address_Line2': 'PENN', 'address_POBox': '', 'address_PostCode': 'WV4 5PJ', 'address_PostTown': 'WOLVERHAMPTON', 'ceased_on': '', 'company_id': '05957738', 'country_of_residence': 'UNITED KINGDOM', 'forename': 'David', 'middle_name': 'Ian', 'name': 'MR DAVID IAN BROMLEY', 'nationality': 'BRITISH', 'officer_kind': 'DIRECTOR', 'person_uid': '11594785', 'source_url': 'https://beta.companieshouse.gov.uk/company/05957738', 'surname': 'Bromley', 'title': 'Mr', 'uid': 'BROMLEY_ian_david:05/1970', 'Citizen_of': 'GB', 'Registered_in': '', 'Resident_in': ''}

# %% [markdown]
# ## Looping through all of the data and pushing it into Neo4j

# %%
from neo4j.v1 import GraphDatabase
driver = GraphDatabase.driver("bolt://10.0.0.1:7687", auth=("myusername", "mypassword"))

# %%
num=0
done=0
chunks = pd.read_csv(master_path+'officers.csv', chunksize=100000)
for chunk in chunks:
    input_data = officer_etl(chunk)
    num+=1
    done+=len(input_data)
    print(num)
    if len(input_data) > 0:
        with driver.session() as session:
            session.run(("UNWIND {list} AS d "
                         "MERGE (c:Person {uid: d.uid}) "
                         "ON CREATE SET c.forename=d.forename, "
                         "c.middle_name=d.middle_name, "
                         "c.surname=d.surname, "
                         "c.title=d.title, "
                         "c.fullname=d.name, "
                         "c.dob=d.DOB, "
                         "c.person_uid=d.person_uid, "
                         "c.nationality=d.nationality, "
                         "c.address_Line1=d.address_Line1, "
                         "c.address_Line2=d.address_Line2, "
                         "c.address_PostTown=d.address_PostTown, "
                         "c.address_County=d.address_County, "
                         "c.address_PostCode=d.address_Postcode, "                 
                         "c.address_Country=d.address_Country, "                 
                         "c.uri=d.source_url;"), {"list": input_data})

        with driver.session() as session:
            session.run(("UNWIND {list} AS d "
                         "MATCH (c:Person {uid: d.uid}) "
                         "MERGE (country:Country {code: d.Registered_in}) "
                         "MERGE (c)-[:REGISTERED_IN]->(country);"), {"list": input_data})

        with driver.session() as session:
            session.run(("UNWIND {list} AS d "
                         "MATCH (c:Person {uid: d.uid}) "
                         "MERGE (country:Country {code: d.Citizen_of}) "
                         "MERGE (c)-[:CITIZEN_OF]->(country);"), {"list": input_data})

        with driver.session() as session:
            session.run(("UNWIND {list} AS d "
                         "MATCH (p:Person {uid: d.uid}) "
                         "SET p:Officer;"), {"list": input_data})    

        with driver.session() as session:
            session.run(("UNWIND {list} AS d "
                         "MATCH (p:Person {uid: d.uid}) "
                         "MERGE (c:Company {uid: d.company_id}) "
                         "CREATE (p)-[r:IS_OFFICER_OF {type: d.officer_kind, ceased_on: d.ceased_on}]->(c);"), {"list": input_data})
        print("Finished chunk...{}%".format(done/40386527))
    else:
        print("No records in this chunk")
print("DONE!")
# Out:
# 1
# Finished chunk...0.0010879618344008634%
# 2
# DONE!
